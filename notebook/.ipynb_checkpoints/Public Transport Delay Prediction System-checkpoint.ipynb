# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib
import warnings 
warnings.filterwarnings('ignore')

# %%
#load data
df = pd.read_csv("../data/public_transport_delays.csv")

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rahul\\Documents\\Kaggle\\Transport delay predictor\\notebook'

# %%
print(df.head())
print("Shape: ",df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
#   trip_id        date      time transport_type  route_id origin_station  \
# 0  T00000  2023-01-01  05:00:00           Tram  Route_15     Station_31
# 1  T00001  2023-01-01  05:15:00          Metro  Route_12     Station_49
# 2  T00002  2023-01-01  05:30:00            Bus  Route_16     Station_29
# 3  T00003  2023-01-01  05:45:00           Tram  Route_19     Station_26
# 4  T00004  2023-01-01  06:00:00           Tram   Route_8     Station_18
#
#   destination_station scheduled_departure scheduled_arrival  \
# 0           Station_6            05:02:00          05:55:00
# 1          Station_32            05:16:00          05:55:00
# 2          Station_42            05:33:00          06:17:00
# 3          Station_18            05:49:00          06:08:00
# 4          Station_15            06:00:00          06:35:00
#
#    actual_departure_delay_min  ...  wind_speed_kmh precipitation_mm  \
# 0                          12  ...              46             13.0
# ...

# %%
# convert datetime
for col in df.columns:
    if "time" in col.lower() or "date" in col.lower():
        try:
            df[col] = pd.to_datetime(df[col])
        except Exception:
            pass

# create combined datetime
df["scheduled_time"] = pd.to_datetime(
    df["date"].astype(str) + " " + df["time"].astype(str),
    errors="coerce"
)

# feature engineering 
#Extract time features from scheduled_time
if "scheduled_time" in df.columns and pd.api.types.is_datetime64_any_dtype(df["scheduled_time"]):
    df["hour"] = df["scheduled_time"].dt.hour
    df["day_of_week"] = df["scheduled_time"].dt.dayofweek
    df["month"] = df["scheduled_time"].dt.month
    df["is_weekend"] = (df["day_of_week"] >= 5).astype(int)
    df["is_peak_hour"] = df["hour"].apply(
        lambda x: 1 if (7 <= x <= 9 or 17 <= x <= 19) else 0
    )

#drop raw datatime columns - because models need numeric features.
datetime_cols = df.select_dtypes(include=["datetime64[ns]","datetimetz"]).columns.tolist()
df.drop(columns = datetime_cols, inplace = True)

# %%
#Encode Categoricals

label_encoders = {}
cat_cols = df.select_dtypes(include=['object','category']).columns.tolist()

#remove target if accidently in cat_cols

target_col = "delayed"
if target_col in cat_cols:
    cat_cols.remove(target_col)
for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

print("Encoded columns: ", cat_cols)
# Out:
# Encoded columns:  ['trip_id', 'transport_type', 'route_id', 'origin_station', 'destination_station', 'scheduled_departure', 'scheduled_arrival', 'weather_condition', 'event_type', 'season']

# %%
# Define features & Target

drop_cols = [target_col]
X = df.drop(columns = drop_cols)
Y = df[target_col]

print("\nFeatures used:", X.columns.tolist())
print("Target: ", target_col)
# Out:
# Features used: ['trip_id', 'transport_type', 'route_id', 'origin_station', 'destination_station', 'scheduled_departure', 'scheduled_arrival', 'actual_departure_delay_min', 'actual_arrival_delay_min', 'weather_condition', 'temperature_C', 'humidity_percent', 'wind_speed_kmh', 'precipitation_mm', 'event_type', 'event_attendance_est', 'traffic_congestion_index', 'holiday', 'peak_hour', 'weekday', 'season', 'hour', 'day_of_week', 'month', 'is_weekend', 'is_peak_hour']
# Target:  delayed

# %%
#Train / Test Split

X_train, X_test, Y_train, Y_test = train_test_split(
    X,Y, test_size = 0.2, random_state = 42,  stratify= Y
)

# %%
#Training LIGHTGBM model

model = lgb.LGBMRegressor(
    n_estimators = 500,
    learning_rate = 0.05,
    num_leaves = 63,
    max_depth = -1,
    subsample = 0.8,
    colsample_bytree = 0.8,
    random_state = 42,
    n_jobs = -1 ,
    verbose = -1 
)

model.fit(
    X_train, Y_train, 
    eval_set = [(X_test, Y_test)],
    callbacks=[lgb.early_stopping(50,verbose = False),lgb.log_evaluation(50)])
# Out:
# [50]	valid_0's l2: 0.00434796
# [100]	valid_0's l2: 0.000484793
# [150]	valid_0's l2: 0.000308417
# [200]	valid_0's l2: 0.000288847
# [250]	valid_0's l2: 0.000283436
# [300]	valid_0's l2: 0.000281169
# [350]	valid_0's l2: 0.000280041
# [400]	valid_0's l2: 0.000278973
# [450]	valid_0's l2: 0.000278664
# [500]	valid_0's l2: 0.000278343
# LGBMRegressor(colsample_bytree=0.8, learning_rate=0.05, n_estimators=500,
#               n_jobs=-1, num_leaves=63, random_state=42, subsample=0.8,
#               verbose=-1)

# %%
#Evaluate

Y_pred = model.predict(X_test)
mae = mean_absolute_error(Y_test,Y_pred)
rmse = np.sqrt(mean_squared_error(Y_test, Y_pred))
r2 = r2_score(Y_test, Y_pred)

print(f"\n{'='*40}")
print(f" MAE  : {mae: .2f} minutes")
print(f" RMSE : {rmse: .2f} minutes")
print(f" R²   : {r2:.4f}")
print(f"{'='*40}")
# Out:
# ...
#  MAE  :  0.01 minutes
#  RMSE :  0.02 minutes
#  R²   : 0.9985
# ...

# %%
#convert regression output to classification
#y_pred_class = (Y_pred > 0.5).astype(int)

# Classification Metrics
#from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#print("\nClassification Evaluation:")
#print("Accuracy:", accuracy_score(Y_test, y_pred_class))
#print("\nConfusion Matrix:\n", confusion_matrix(Y_test, y_pred_class))
#print("\nReport:\n", classification_report(Y_test, y_pred_class))

# %%
#Save Artifacts

os.makedirs("model", exist_ok = True)
joblib.dump(model,"model/lgbm_model.pkl")
joblib.dump(label_encoders, "model/feature_encoders.pkl")
joblib.dump(X.columns.tolist(),"model/feature_columns.pkl")

print("\n✅Model Saved to model/lgbm_model.pkl")
print("✅Label Encoders saved to model/feature_encoders.pkl")
print("✅Label Columns Saved to model/feature_columns.pkl")
# Out:
# ✅Model Saved to model/lgbm_model.pkl
# ✅Label Encoders saved to model/feature_encoders.pkl
# ✅Label Columns Saved to model/feature_columns.pkl
